# %% [markdown]
# # How does Tobacco Usage Vary Between Different Regions of the World and What is the Reasoning Behind This?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("tobacco_use_ww.csv")
df
# Out:
#      ParentLocationCode         ParentLocation SpatialDimValueCode  \
# 0                  SEAR        South-East Asia                 PRK
# 1                   EUR                 Europe                 AZE
# 2                   AFR                 Africa                 ERI
# 3                   EMR  Eastern Mediterranean                 EGY
# 4                   AFR                 Africa                 GHA
# ...                 ...                    ...                 ...
# 4018                WPR        Western Pacific                 TUV
# 4019                AMR               Americas                 JAM
# 4020                AFR                 Africa                 STP
# 4021                EMR  Eastern Mediterranean                 OMN
# 4022               SEAR        South-East Asia                 TLS
#
#                                    Location  Year      Gender  Value
# 0     Democratic People's Republic of Korea  2018      Female    0.0
# ...

# %% [markdown]
# ### Seperating Data by Region

# %%
df_Asia = df[df["ParentLocation"] == "South-East Asia"]
df_Africa = df[df["ParentLocation"] == "Africa"]
df_Europe = df[df["ParentLocation"] == "Europe"]
df_EastMed = df[df["ParentLocation"] == "Eastern Mediterranean"]
df_WestPac = df[df["ParentLocation"] == "Western Pacific"]
df_Americas = df[df["ParentLocation"] == "Americas"]

# %%
df_AmericasM = df_Americas[df_Americas["Gender"] == "Male"]
df_AmericasF = df_Americas[df_Americas["Gender"] == "Female"]

print(df_AmericasM["Value"].hist(density = True, color = 'forestgreen'))
plt.title('Tobacco Usage in the Americas (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_AmericasF["Value"].hist(density = True, color = 'forestgreen'))
plt.title('Tobacco Usage in the Americas (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_AmericasM["Value"].mean())
print(df_AmericasM["Value"].std())
print(df_AmericasF["Value"].mean())
print(df_AmericasF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 26.095555555555556
# 11.429701688811495
# 11.581666666666665
# 10.582817712039502

# %%
df_AfricaM = df_Africa[df_Africa["Gender"] == "Male"]
df_AfricaF = df_Africa[df_Africa["Gender"] == "Female"]

print(df_AfricaM["Value"].hist(density = True,color = 'sandybrown'))
plt.title('Tobacco Usage in Africa (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()
print(df_AfricaF["Value"].hist(density = True,color = 'sandybrown'))
plt.title('Tobacco Usage in Africa (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_AfricaM["Value"].mean())
print(df_AfricaM["Value"].std())
print(df_AfricaF["Value"].mean())
print(df_AfricaF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 26.18168168168168
# 11.620658051460367
# 5.831531531531532
# 6.032606910890354

# %%
df_AsiaM = df_Asia[df_Asia["Gender"] == "Male"]
df_AsiaF = df_Asia[df_Asia["Gender"] == "Female"]

print(df_AsiaM["Value"].hist(density = True,color = 'indianred'))
plt.title('Tobacco Usage in South-East Asia (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()
print(df_AsiaF["Value"].hist(density = True,color = 'indianred'))
plt.title('Tobacco Usage in South-East Asia (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_AsiaM["Value"].mean())
print(df_AsiaM["Value"].std())
print(df_AsiaF["Value"].mean())
print(df_AsiaF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 57.32098765432099
# 13.637610824933585
# 13.87037037037037
# 11.537963906647963

# %%
df_EastMedM = df_EastMed[df_EastMed["Gender"] == "Male"]
df_EastMedF = df_EastMed[df_EastMed["Gender"] == "Female"]

print(df_EastMedM["Value"].hist(density = True,color = 'navy'))
plt.title('Tobacco Usage in the Eastern Mediterranean (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_EastMedF["Value"].hist(density = True,color = 'navy'))
plt.title('Tobacco Usage in the Eastern Mediterranean (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_EastMedM["Value"].mean())
print(df_EastMedM["Value"].std())
print(df_EastMedF["Value"].mean())
print(df_EastMedF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 37.69841269841269
# 10.124757649460923
# 6.739682539682541
# 9.22265974100816

# %%
df_WestPacM = df_WestPac[df_WestPac["Gender"] == "Male"]
df_WestPacF = df_WestPac[df_WestPac["Gender"] == "Female"]

print(df_WestPacM["Value"].hist(density = True,color = 'olive'))
plt.title('Tobacco Usage in the Western Pacific (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()
print(df_WestPacF["Value"].hist(density = True,color = 'olive'))
plt.title('Tobacco Usage in the Western Pacific (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_WestPacM["Value"].mean())
print(df_WestPacM["Value"].std())
print(df_WestPacF["Value"].mean())
print(df_WestPacF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 46.335858585858574
# 14.762174774789228
# 16.312121212121212
# 14.223950437061937

# %%
df_EuropeM = df_Europe[df_Europe["Gender"] == "Male"]
df_EuropeF = df_Europe[df_Europe["Gender"] == "Female"]

print(df_EuropeM["Value"].hist(density = True,color = 'powderblue'))
plt.title('Tobacco Usage in Europe (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()
print(df_EuropeF["Value"].hist(density = True,color = 'powderblue'))
plt.title('Tobacco Usage in Europe (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Density')
plt.figure()

print(df_EuropeM["Value"].mean())
print(df_EuropeM["Value"].std())
print(df_EuropeF["Value"].mean())
print(df_EuropeF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 38.60023640661939
# 10.601919031372148
# 21.258156028368795
# 10.227980551661746

# %% [markdown]
# ### Relationship Between Usage Value and Average Cigarette Price For Each Region

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df_combined = pd.read_csv("CombinedDataMaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["AvgCigarettePriceDollars"])


df_combined_q = df_combined.dropna()

X = df_combined_q['Value'].values[:,np.newaxis]
y = df_combined_q['AvgCigarettePriceDollars'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Average Price of Cigarette vs Tobacco Usage (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Average Price of Cigarette ($)')
plt.show()

print(model.coef_)
print(model.intercept_)
df_combined.corr()
# Out:
# [-0.08959921]
# 7.922509226510591
#                              Year     Value  AvgCigarettePriceDollars  \
# Year                          NaN       NaN                       NaN
# Value                         NaN  1.000000                 -0.231727
# AvgCigarettePriceDollars      NaN -0.231727                  1.000000
# AvgTaxesAsPctCigarettePrice   NaN  0.251605                  0.503076
# EnforceBansTobaccoAd          NaN  0.150872                  0.005502
# HelpToQuit                    NaN -0.084455                  0.397945
# TobaccoProduction             NaN -0.279595                  0.237755
#
#                              AvgTaxesAsPctCigarettePrice  \
# Year                                                 NaN
# Value                                           0.251605
# AvgCigarettePriceDollars                        0.503076
# AvgTaxesAsPctCigarettePrice                     1.000000
# EnforceBansTobaccoAd                            0.237957
# ...

# %%
df_combined = pd.read_csv("CombinedDataMaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["AvgTaxesAsPctCigarettePrice"])


df_combined_r = df_combined.dropna()

X = df_combined_r['Value'].values[:,np.newaxis]
y = df_combined_r['AvgTaxesAsPctCigarettePrice'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Sum of Taxes on Cigarettes vs Tobacco Usage (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Sum of Taxes on Cigarettes ($)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [-0.41917968]
# 83.74866040512606

# %%
df_combined = pd.read_csv("CombinedDataMaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["EnforceBansTobaccoAd"])


df_combined_s = df_combined.dropna()

X = df_combined_s['Value'].values[:,np.newaxis]
y = df_combined_s['EnforceBansTobaccoAd'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Enforcement of Bans on Tobacco Ads vs Tobacco Usage (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Enforcement of Bans on Tobacco Ads (Level)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [0.00151794]
# 3.9862916691368415

# %%
df_combined = pd.read_csv("CombinedDataMaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["HelpToQuit"])


df_combined_t = df_combined.dropna()

X = df_combined_t['Value'].values[:,np.newaxis]
y = df_combined_t['HelpToQuit'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Aids to Help Quit Tobacco vs Tobacco Usage (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Aids to Help Quit Tobacco (Aid Level)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [-0.03300045]
# 5.330212660889824

# %%
df_combined = pd.read_csv("CombinedDataMaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["TobaccoProduction"])


df_combined_u = df_combined.dropna()

X = df_combined_u['Value'].values[:,np.newaxis]
y = df_combined_u['TobaccoProduction'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Tobacco Production vs Tobacco Usage (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Tobacco Production (Metric Tons)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [51.24962427]
# 17536.559633537643

# %%
df_combined = pd.read_csv("CombinedDataFemaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["AvgCigarettePriceDollars"])


df_combined_v = df_combined.dropna()

X = df_combined_v['Value'].values[:,np.newaxis]
y = df_combined_v['AvgCigarettePriceDollars'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Average Price of Cigarette vs Tobacco Usage (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Average Price of Cigarette ($)')
plt.show()

print(model.coef_)
print(model.intercept_)
df_combined.corr()
# Out:
# [0.12957855]
# 2.0956683053712126
#                              Year     Value  AvgCigarettePriceDollars  \
# Year                          NaN       NaN                       NaN
# Value                         NaN  1.000000                  0.374553
# AvgCigarettePriceDollars      NaN  0.374553                  1.000000
# AvgTaxesAsPctCigarettePrice   NaN  0.657741                  0.503076
# EnforceBansTobaccoAd          NaN  0.194098                  0.005502
# HelpToQuit                    NaN  0.129639                  0.397945
# TobaccoProduction             NaN -0.161903                  0.237755
#
#                              AvgTaxesAsPctCigarettePrice  \
# Year                                                 NaN
# Value                                           0.657741
# AvgCigarettePriceDollars                        0.503076
# AvgTaxesAsPctCigarettePrice                     1.000000
# EnforceBansTobaccoAd                            0.237957
# ...

# %%
df_combined = pd.read_csv("CombinedDataFemaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["AvgTaxesAsPctCigarettePrice"])


df_combined_r = df_combined.dropna()

X = df_combined_r['Value'].values[:,np.newaxis]
y = df_combined_r['AvgTaxesAsPctCigarettePrice'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Sum of Taxes on Cigarettes vs Tobacco Usage (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Sum of Taxes on Cigarettes ($)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [1.12976727]
# 46.58427223198837

# %%
df_combined = pd.read_csv("CombinedDataFemaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["EnforceBansTobaccoAd"])


df_combined_s = df_combined.dropna()

X = df_combined_s['Value'].values[:,np.newaxis]
y = df_combined_s['EnforceBansTobaccoAd'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Enforcement of Bans on Tobacco Ads vs Tobacco Usage (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Enforcement of Bans on Tobacco Ads (Level)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [0.00129239]
# 4.0190295506360965

# %%
df_combined = pd.read_csv("CombinedDataFemaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["HelpToQuit"])


df_combined_t = df_combined.dropna()

X = df_combined_t['Value'].values[:,np.newaxis]
y = df_combined_t['HelpToQuit'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Aids to Help Quit Tobacco vs Tobacco Usage (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Aids to Help Quit Tobacco (Aid Level)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [0.00904205]
# 3.915904562399385

# %%
df_combined = pd.read_csv("CombinedDataFemaleFinal.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["TobaccoProduction"])


df_combined_u = df_combined.dropna()

X = df_combined_u['Value'].values[:,np.newaxis]
y = df_combined_u['TobaccoProduction'].values


model = LinearRegression()
model.fit(X,y)
plt.scatter(X, y)
plt.plot(X, model.predict(X),color='k')
plt.title('Tobacco Production vs Tobacco Usage (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Tobacco Production (Metric Tons)')
plt.show()

print(model.coef_)
print(model.intercept_)
# Out:
# [-82.69667004]
# 21031.73878848917
