# %% [markdown]
# # How does Tobacco Usage Vary Between Different Regions of the World and What is the Reasoning Behind This?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("tobacco_use_ww.csv")
df
# Out:
#      ParentLocationCode         ParentLocation SpatialDimValueCode  \
# 0                  SEAR        South-East Asia                 PRK
# 1                   EUR                 Europe                 AZE
# 2                   AFR                 Africa                 ERI
# 3                   EMR  Eastern Mediterranean                 EGY
# 4                   AFR                 Africa                 GHA
# ...                 ...                    ...                 ...
# 4018                WPR        Western Pacific                 TUV
# 4019                AMR               Americas                 JAM
# 4020                AFR                 Africa                 STP
# 4021                EMR  Eastern Mediterranean                 OMN
# 4022               SEAR        South-East Asia                 TLS
#
#                                    Location  Year      Gender  Value
# 0     Democratic People's Republic of Korea  2018      Female    0.0
# ...

# %%
len(df_Africa) + len(df_WestPac) + len(df_Asia) + len(df_EastMed) + len(df_Europe) + len(df_Americas)
# Out:
# 4023

# %% [markdown]
# ### Seperating Data by Region

# %%
df_Asia = df[df["ParentLocation"] == "South-East Asia"]
df_Africa = df[df["ParentLocation"] == "Africa"]
df_Europe = df[df["ParentLocation"] == "Europe"]
df_EastMed = df[df["ParentLocation"] == "Eastern Mediterranean"]
df_WestPac = df[df["ParentLocation"] == "Western Pacific"]
df_Americas = df[df["ParentLocation"] == "Americas"]

# %%
df_AmericasM = df_Americas[df_Americas["Gender"] == "Male"]
df_AmericasF = df_Americas[df_Americas["Gender"] == "Female"]

print(df_AmericasM["Value"].hist(color = 'forestgreen'))
plt.title('Tobacco Usage in the Americas (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_AmericasF["Value"].hist(color = 'forestgreen'))
plt.title('Tobacco Usage in the Americas (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_AmericasM["Value"].mean())
print(df_AmericasM["Value"].std())
print(df_AmericasF["Value"].mean())
print(df_AmericasF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 26.095555555555556
# 11.429701688811495
# 11.581666666666665
# 10.582817712039502

# %%
df_AfricaM = df_Africa[df_Africa["Gender"] == "Male"]
df_AfricaF = df_Africa[df_Africa["Gender"] == "Female"]

print(df_AfricaM["Value"].hist(color = 'sandybrown'))
plt.title('Tobacco Usage in Africa (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()
print(df_AfricaF["Value"].hist(color = 'sandybrown'))
plt.title('Tobacco Usage in Africa (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_AfricaM["Value"].mean())
print(df_AfricaM["Value"].std())
print(df_AfricaF["Value"].mean())
print(df_AfricaF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 26.18168168168168
# 11.620658051460367
# 5.831531531531532
# 6.032606910890354

# %%
df_AsiaM = df_Asia[df_Asia["Gender"] == "Male"]
df_AsiaF = df_Asia[df_Asia["Gender"] == "Female"]

print(df_AsiaM["Value"].hist(color = 'indianred'))
plt.title('Tobacco Usage in Asia (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()
print(df_AsiaF["Value"].hist(color = 'indianred'))
plt.title('Tobacco Usage in Asia (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_AsiaM["Value"].mean())
print(df_AsiaM["Value"].std())
print(df_AsiaF["Value"].mean())
print(df_AsiaF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 57.32098765432099
# 13.637610824933585
# 13.87037037037037
# 11.537963906647963

# %%
df_EastMedM = df_EastMed[df_EastMed["Gender"] == "Male"]
df_EastMedF = df_EastMed[df_EastMed["Gender"] == "Female"]

print(df_EastMedM["Value"].hist(color = 'navy'))
plt.title('Tobacco Usage in the Eastern Mediterranean (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_EastMedF["Value"].hist(color = 'navy'))
plt.title('Tobacco Usage in the Eastern Mediterranean (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_EastMedM["Value"].mean())
print(df_EastMedM["Value"].std())
print(df_EastMedF["Value"].mean())
print(df_EastMedF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 37.69841269841269
# 10.124757649460923
# 6.739682539682541
# 9.22265974100816

# %%
df_WestPacM = df_WestPac[df_WestPac["Gender"] == "Male"]
df_WestPacF = df_WestPac[df_WestPac["Gender"] == "Female"]

print(df_WestPacM["Value"].hist(color = 'olive'))
plt.title('Tobacco Usage in the Western Pacific (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()
print(df_WestPacF["Value"].hist(color = 'olive'))
plt.title('Tobacco Usage in the Western Pacific (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_WestPacM["Value"].mean())
print(df_WestPacM["Value"].std())
print(df_WestPacF["Value"].mean())
print(df_WestPacF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 46.335858585858574
# 14.762174774789228
# 16.312121212121212
# 14.223950437061937

# %%
df_EuropeM = df_Europe[df_Europe["Gender"] == "Male"]
df_EuropeF = df_Europe[df_Europe["Gender"] == "Female"]

print(df_EuropeM["Value"].hist(color = 'powderblue'))
plt.title('Tobacco Usage in Europe (Males)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()
print(df_EuropeF["Value"].hist(color = 'powderblue'))
plt.title('Tobacco Usage in Europe (Females)', fontsize=20)
plt.xlabel('Tobacco Usage (%)')
plt.ylabel('Count')
plt.figure()

print(df_EuropeM["Value"].mean())
print(df_EuropeM["Value"].std())
print(df_EuropeF["Value"].mean())
print(df_EuropeF["Value"].std())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# 38.60023640661939
# 10.601919031372148
# 21.258156028368795
# 10.227980551661746

# %% [markdown]
# ### Relationship Between Usage Value and Average Cigarette Price For Each Region

# %%
df_combined = pd.read_csv("CombinedDataMale.csv")
df_combined_e = df_combined[df_combined["ParentLocation"] == "Europe"]

df_combined_e.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='AvgCigarettePriceDollars'>

# %%
df_combined = pd.read_csv("CombinedDataMale.csv")
df_combined_a = df_combined[df_combined["ParentLocation"] == "Americas"]

df_combined_a.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='AvgCigarettePriceDollars'>

# %%
df_combined = pd.read_csv("CombinedDataMale.csv")
df_combined_afr = df_combined[df_combined["ParentLocation"] == "Africa"]

df_combined_afr.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='AvgCigarettePriceDollars'>

# %%
df_combined = pd.read_csv("CombinedDataMale.csv")
df_combined_wp = df_combined[df_combined["ParentLocation"] == "Western Pacific"]

df_combined_wp.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='AvgCigarettePriceDollars'>

# %%
df_combined = pd.read_csv("CombinedDataMale.csv")
df_combined_em = df_combined[df_combined["ParentLocation"] == "Eastern Mediterranean"]

df_combined_em.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='AvgCigarettePriceDollars'>

# %%
df_combined = pd.read_csv("CombinedDataMale.csv")
df_combined_asia = df_combined[df_combined["ParentLocation"] == "South-East Asia"]

df_combined_asia.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='AvgCigarettePriceDollars'>

# %%
import numpy as np
df_combined = pd.read_csv("CombinedDataMale.csv")
x = np.array(df_combined["Value"])
y = np.array(df_combined["AvgCigarettePriceDollars"])
a, b = np.polyfit(x,y,1)

df_combined.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
plt.plot(x, a*x + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/kv/9gcrb6sj76x7l5r3q4m0s8_w0000gn/T/ipykernel_91856/2531862445.py in <module>
#       3 x = np.array(df_combined["Value"])
#       4 y = np.array(df_combined["AvgCigarettePriceDollars"])
# ----> 5 a, b = np.polyfit(x,y,1)
#       6
#       7 df_combined.plot.scatter(x='Value', y="AvgCigarettePriceDollars")
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     619     """
#     620     order = int(deg) + 1
# --> 621     x = NX.asarray(x) + 0.0
#     622     y = NX.asarray(y) + 0.0
#     623
#
# TypeError: can only concatenate str (not "float") to str
